# %%
import pandas as pd
from IPython.display import HTML

# %%
html_csv = pd.read_csv("Api_Homework_6.csv")

# %%
html_csv.head()
# Out:
#          City  Temperature (Celcius)  Humidity (%)  Cloudiness (%)  \
# 0  Tolaga Bay                   4.88            93              21
# 1   Busselton                   8.84            72              61
# 2      Albany                  25.00            33              20
# 3     Rikitea                  21.78            93             100
# 4     Mataura                   7.78            92             100
#
#    Wind Speed (mph)  Latitude Coord.  Longitude Coord. Country
# 0              1.31           -38.37            178.30      NZ
# 1              6.88           -33.64            115.35      AU
# 2              2.10            42.65            -73.75      US
# 3              8.10           -23.12           -134.97      PF
# 4              6.71           -46.19            168.86      NZ

# %%
html_csv.to_html(classes="table")
# Out:
# <table border="1" class="dataframe table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Temperature (Celcius)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#       <th>Latitude Coord.</th>
#       <th>Longitude Coord.</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tolaga Bay</td>
#       <td>4.88</td>
#       <td>93</td>
#       <td>21</td>
#       <td>1.31</td>
#       <td>-38.37</td>
#       <td>178.30</td>
#       <td>NZ</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Busselton</td>
#       <td>8.84</td>
#       <td>72</td>
#       <td>61</td>
#       <td>6.88</td>
#       <td>-33.64</td>
#       <td>115.35</td>
#       <td>AU</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albany</td>
#       <td>25.00</td>
#       <td>33</td>
#       <td>20</td>
#       <td>2.10</td>
# ...
